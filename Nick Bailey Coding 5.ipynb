# %% [markdown]
# # Numerically solving the Schrodinger equation
#
# In this assignment you will use [<tt>qmsolve</tt>](https://github.com/quantum-visualizations/qmsolve) to solve the time-independent Schrodinger equation in one dimension and plot the solutions.
#
# ### First, install <tt>qmsolve</tt> in one of two ways:
# <ul>
#     <li>From a <tt>unix</tt> command line, type <tt>pip install qmsolve</tt></li>
#     <li>Put the following commands in a code cell in this notebook and execute:<br />
#         <tt>import sys</tt><br />
#         <tt>!{sys.executable} -m pip install qmsolve</tt></li>
# </ul>

# %% [markdown]
# ### Homework problems:
#
# <ol start=0>
#     <li>Follow the link to the <tt>qmsolve</tt> GitHub page above. Click the link for the <tt>examples</tt> folder, then click on the <tt>eigenstate solver examples</tt> folder. Finally, click on <tt>1D_harmonic_oscillator.py</tt> to see a short code snippet that will calculate wavefunctions for a simple harmonic oscillator (SHO).</li>
#     <li><tt>1D_harmonic_oscillator.py</tt> imports the <tt>Hamiltonian</tt> class from <tt>qmsolve</tt>. In quantum mechanics, what is a Hamiltonian? Please use multiple sources to formulate your answer and cite those sources. For this problem, crowd-sourced references such as Wikipedia and stackexchange are acceptable.</li>
#     <li>Which force law is defined in the function <tt>harmonic_oscillator()</tt> in cell 2 of this notebook?</li>
#     <li>What are the eigenstates referred to in lines 22 and 23 in <tt>1D_harmonic_oscillator.py</tt>? Again, please use multiple sources to formulate your answer and cite those sources.
#     <li>Code cells 1 and 2 below contain imported code from <tt>1D_harmonic_oscillator.py</tt>, including a visualization of eigenstate 0 of the SHO. In subsequent code cells, plot any five SHO eigenstates of your choice.</li>
# </ol>
#
# Note: you can write your answers to the non-code problems in a markdown cell. From within a new notebook cell, click the box with a double arrow that says "Code" and change to "Markdown". Then you can just type in the cell like a regular text file.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
# !{sys.executable} -m pip install qmsolve
from qmsolve import Hamiltonian, SingleParticle, init_visualization, Å, eV
# Out:
# Collecting qmsolve
#   Downloading qmsolve-2.0.0-py3-none-any.whl (35 kB)
# Collecting progressbar
#   Downloading progressbar-2.5.tar.gz (10 kB)
# Requirement already satisfied: h5py in c:\users\nicol\anaconda3\lib\site-packages (from qmsolve) (3.6.0)
# Requirement already satisfied: matplotlib in c:\users\nicol\anaconda3\lib\site-packages (from qmsolve) (3.5.1)
# Requirement already satisfied: numpy in c:\users\nicol\anaconda3\lib\site-packages (from qmsolve) (1.21.5)
# Requirement already satisfied: scipy in c:\users\nicol\anaconda3\lib\site-packages (from qmsolve) (1.7.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\nicol\anaconda3\lib\site-packages (from matplotlib->qmsolve) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\nicol\anaconda3\lib\site-packages (from matplotlib->qmsolve) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\nicol\anaconda3\lib\site-packages (from matplotlib->qmsolve) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nicol\anaconda3\lib\site-packages (from matplotlib->qmsolve) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\nicol\anaconda3\lib\site-packages (from matplotlib->qmsolve) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nicol\anaconda3\lib\site-packages (from matplotlib->qmsolve) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nicol\anaconda3\lib\site-packages (from matplotlib->qmsolve) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\nicol\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->qmsolve) (1.16.0)
# Building wheels for collected packages: progressbar
#   Building wheel for progressbar (setup.py): started
#   Building wheel for progressbar (setup.py): finished with status 'done'
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12082 sha256=d8a0065f4ec4dc036f878167b0ad651928a4df6195a3a26b6fc08d66a313355d
#   Stored in directory: c:\users\nicol\appdata\local\pip\cache\wheels\d7\d9\89\a3f31c76ff6d51dc3b1575628f59afe59e4ceae3f2748cd7ad
# Successfully built progressbar
# Installing collected packages: progressbar, qmsolve
# Successfully installed progressbar-2.5 qmsolve-2.0.0

# %% [markdown]
# Question 1: A Hamiltonian is a mathematical description that describes the total energy of a system (generally kinetic + potential). In quantum mechanics, it acts as an operator on the wave function of a system. It is closely related to the energy eigenvalues, which is a set of the possible outcomes obtained from measuring a system's total energy. Because of this relation and the description of a system's total energy, it helps determine the behaviors and dynamics of the system/particle it's being applied to.
#
# Sources:
# http://hyperphysics.phy-astr.gsu.edu/hbase/quantum/hamil.html
# https://www.youtube.com/watch?v=BusR0WQ_Gxo
# https://en.wikipedia.org/wiki/Hamiltonian_(quantum_mechanics)

# %%
# Harmonic oscillator potential
def harmonic_oscillator(particle):
    k = 100 * eV / Å**2
    return 0.5 * k * particle.x**2

# Define the Hamiltonian
H = Hamiltonian(particles = SingleParticle(), potential = harmonic_oscillator, 
                spatial_ndim = 1, N = 512, extent = 20*Å)

#Diagonalize the Hamiltonian and compute the eigenstates
eigenstates = H.solve(max_states = 30)

# Print out the energies of the eigenstates
print(eigenstates.energies) # the printed energies are expressed in eV

# Visualize the Eigenstates
visualization = init_visualization(eigenstates)
visualization.plot_eigenstate(0)
# Out:
# Computing...
# Took 0.017168045043945312
# [ 13.8243627   41.46350403  69.08346722  96.68423227 124.26577906
#  151.82808744 179.37113718 206.89490796 234.39937942 261.8845311
#  289.35034249 316.79679298 344.22386192 371.63152856 399.01977209
#  426.38857162 453.73790619 481.06775475 508.3780962  535.66890934
#  562.9401729  590.19186555 617.42396585 644.63645231 671.82930335
#  699.00249732 726.15601246 753.28982697 780.40391895 807.49826642]

# %% [markdown]
# Question 2: The force law detailed above in the harmonic_oscillator() function is Hooke's Law (more specifically, the energy stored in a spring).

# %% [markdown]
# Question 3: An eigenstate is a state of a quantized system where one of the properties/variables defining the state has a particular value. This value is associated with the state of the system, and multiples of this value are considered eigenvalues.
#
# Sources:
# https://www.merriam-webster.com/dictionary/eigenstate#:~:text=noun,has%20a%20determinate%20fixed%20value
# https://phys.libretexts.org/Bookshelves/Quantum_Mechanics/Introductory_Quantum_Mechanics_(Fitzpatrick)/03%3A_Fundamentals_of_Quantum_Mechanics/3.08%3A_Eigenstates_and_Eigenvalues

# %%
# Harmonic oscillator potential
def harmonic_oscillator(particle):
    k = 100 * eV / Å**2
    return 0.5 * k * particle.x**2

# Define the Hamiltonian
H = Hamiltonian(particles = SingleParticle(), potential = harmonic_oscillator, 
                spatial_ndim = 1, N = 512, extent = 20*Å)

#Diagonalize the Hamiltonian and compute the eigenstates
eigenstates = H.solve(max_states = 30)

# Print out the energies of the eigenstates
print(eigenstates.energies) # the printed energies are expressed in eV

# Visualize the Eigenstates
visualization = init_visualization(eigenstates)
visualization.plot_eigenstate(1)
visualization.plot_eigenstate(2)
visualization.plot_eigenstate(3)
visualization.plot_eigenstate(6)
visualization.plot_eigenstate(10)
# Out:
# Computing...
# Took 0.026329517364501953
# [ 13.8243627   41.46350403  69.08346722  96.68423227 124.26577906
#  151.82808744 179.37113718 206.89490796 234.39937942 261.8845311
#  289.35034249 316.79679298 344.22386192 371.63152856 399.01977209
#  426.38857162 453.73790619 481.06775475 508.3780962  535.66890934
#  562.9401729  590.19186555 617.42396585 644.63645231 671.82930335
#  699.00249732 726.15601246 753.28982697 780.40391895 807.49826642]

# %% [markdown]
# Question 5: The x-axis is the distance, in Angstroms.
#
# Question 6: It's plotting the wave function. I can tell because if I sum individual points (ie peaks of higher eigenstates) the sum is greater than 1. Alternatively, you can't have a negative probability, and the functions have negative values.

# %% [markdown]
# <ol start=5>
#     <li>What is on the x-axis of your plots?</li>
#     <li>Are your plots showing wave functions $\psi(x)$ or probability functions $\psi^*(x) \psi(x)$? How do you know?</li>
# </ol>
#
# ### New potential: infinite square well
#
# Below I define the infinite square well potential and plot the two lowest-energy eigenstates (compare to Figure 6.3 in your textbook).

# %%
# 8 angstrom-wide infinite square well
def infinite_square_well(particle):
    potential = np.zeros_like(particle.x)
    out_of_bounds = np.abs(particle.x) > 4*Å
    potential[out_of_bounds] = np.inf
    return potential

# Define the Hamiltonian of the infinite square well
H_sw = Hamiltonian(particles = SingleParticle(), potential = infinite_square_well, 
                   spatial_ndim = 1, N = 512, extent = 10*Å)

# Diagonalize the Hamiltonian and compute the eigenstates
eigenstates_sw = H_sw.solve(max_states = 30)

print(eigenstates_sw.energies)

# Visualize the infinite square well eigenstates
visualization_sw = init_visualization(eigenstates_sw)
visualization_sw.plot_eigenstate(0)
visualization_sw.plot_eigenstate(1)
# Out:
# Computing...
# Took 0.011141061782836914
# [  0.58926935   2.35704264   5.30321556   9.4276143   14.7299955
#   21.21004635  28.8673845   37.70155819  47.71204619  58.89825789
#   71.2595333   84.79514311  99.50428872 115.3861023  132.43964681
#  150.6639161  170.05783494 190.6202591  212.34997539 235.24570176
#  259.30608737 284.52971266 310.91508944 338.46066097 367.16480207
#  397.0258192  428.04195057 460.21136622 493.53216816 528.00239048]

# %% [markdown]
# <ol start=7>
#     <li>Plot any three infinite square well eigenstates of your choice.</li>
#     <li>What property do the infinite square well eigenstates have that's different than the SHO eigenstates? (Hint: think about the properties of valid wave functions we discussed in class)</li>
#     <li>What is the relationship between the number of extrema (maxima plus minima) in each eigenstate plot and the quantum number of the eigenstate?</li>
# </ol>

# %%
# 8 angstrom-wide infinite square well
def infinite_square_well(particle):
    potential = np.zeros_like(particle.x)
    out_of_bounds = np.abs(particle.x) > 4*Å
    potential[out_of_bounds] = np.inf
    return potential

# Define the Hamiltonian of the infinite square well
H_sw = Hamiltonian(particles = SingleParticle(), potential = infinite_square_well, 
                   spatial_ndim = 1, N = 512, extent = 10*Å)

# Diagonalize the Hamiltonian and compute the eigenstates
eigenstates_sw = H_sw.solve(max_states = 30)

print(eigenstates_sw.energies)

# Visualize the infinite square well eigenstates
visualization_sw = init_visualization(eigenstates_sw)
visualization_sw.plot_eigenstate(1)
visualization_sw.plot_eigenstate(15)
visualization_sw.plot_eigenstate(25)
# Out:
# Computing...
# Took 0.008947134017944336
# [  0.58926935   2.35704264   5.30321556   9.4276143   14.7299955
#   21.21004635  28.8673845   37.70155819  47.71204619  58.89825789
#   71.2595333   84.79514311  99.50428872 115.3861023  132.43964681
#  150.6639161  170.05783494 190.6202591  212.34997539 235.24570176
#  259.30608737 284.52971266 310.91508944 338.46066097 367.16480207
#  397.0258192  428.04195057 460.21136622 493.53216816 528.00239048]

# %% [markdown]
# Question 8: The infinite square well eigenstates have to satisfy the boundary conditions at the walls psi(0) = 0, psi(L) = 0. The simple harmonic oscillator eigenstates don't have to satisfy these boundary conditions.

# %% [markdown]
# Question 9: There's always 1 more extrema than the quantum number of the eigenstate. So an eigenstate with a quantum number of 0 has 1 extrema (seems to be a minimum), but an eigenstate with a quantum number of 10 would have 11 extrema (I'd assume 5 maximums and 6 minimums).

# %% [markdown]
# ### Now it's your turn to define a potential
#
# <ol start=10>
#     <li>Write a function that defines a <em>finite square-well</em> potential (textbook section 5.4). You can choose the width of the well in Angstroms and the potential at the walls in eV. Calculate the finite square-well Hamiltonian and plot any five eigenstates you choose.</li>
#     <li>Based on your plots, do you think a particle can get out of the finite square-well potential no matter its quantum number $n$?</li>
# </ol>

# %%
def finite_square_well(particle):
    potential = np.zeros_like(particle.x)
    width = 10*Å
    depth = 5*Å
    out_of_bounds = np.abs(particle.x) > width/2
    potential[out_of_bounds] = depth
    return potential

# Defining the Hamiltonian of the finite square well
H_fsw = Hamiltonian(particles = SingleParticle(), potential = finite_square_well, 
                   spatial_ndim = 2, N = 512, extent = 5*Å)

# Diagonalize the Hamiltonian and compute the eigenstates
eigenstates_fsw = H_fsw.solve(max_states = 30)

print(eigenstates_fsw.energies)

# Visualize the finite square well eigenstates
visualization_fsw = init_visualization(eigenstates_fsw)
visualization_fsw.plot_eigenstate(5)
visualization_fsw.plot_eigenstate(10)
visualization_fsw.plot_eigenstate(20)
# Out:
# Computing...
# Took 10.293518543243408
# [ 2.99651533  7.49123214  7.49123214 11.98594894 14.98223952 14.98223952
#  19.47695633 19.47695633 25.46925655 25.46925655 26.96796371 29.96397336
#  29.96397336 37.45498074 37.45498074 38.95188993 38.95188993 43.44660674
#  43.44660674 47.94199777 50.93761412 50.93761412 55.42963402 55.42963402
#  59.92435083 59.92435083 61.42463115 61.42463115 67.41535821 67.41535821]

# %% [markdown]
# Question 11: I don't think the particle can get out of the finite square well regardless of its quantum number. As the quantum number increases, I think it has a decreasing chance of getting out, as the areas seem thinner (if these are even the right graphs). Conceptually, I believe there should be an ideal quantum number for getting out of the square well, but it's entirely dependent on the potential walls.
